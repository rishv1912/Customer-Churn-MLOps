# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly as go
import seaborn as sns

# %%
df_path = "../data/customer_data.csv"
df = pd.read_csv(df_path)

# %%
df.head()
# Out:
#     "recordID" state  account_length  area_code international_plan  \
# 0            1    HI             101        510                 no
# 1            2    MT             137        510                 no
# 2            3    OH             103        408                 no
# 3            4    NM              99        415                 no
# 4            5    SC             108        415                 no
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0              no                      0               70.9              123
# 1              no                      0              223.6               86
# 2             yes                     29              294.7               95
# 3              no                      0              216.8              123
# 4              no                      0              197.4               78
#
#    total_day_charge  ...  total_eve_charge  total_night_minutes  \
# 0             12.05  ...             18.01                236.0
# 1             38.01  ...             20.81                 94.2
# 2             50.10  ...             20.17                300.3
# 3             36.86  ...             10.74                220.6
# 4             33.56  ...             10.54                204.5
#
#    total_night_calls  total_night_charge  total_intl_minutes  \
# 0                 73               10.62                10.6
# 1                 81                4.24                 9.5
# 2                127               13.51                13.7
# 3                 82                9.93                15.7
# 4                107                9.20                 7.7
#
#    total_intl_calls  total_intl_charge  number_customer_service_calls  churn  \
# 0                 3               2.86                              3     no
# 1                 7               2.57                              0     no
# 2                 6               3.70                              1     no
# 3                 2               4.24                              1     no
# 4                 4               2.08                              2     no
#
#    customer_id
# 0   23383607.0
# 1   22550362.0
# 2   59063354.0
# 3   25464504.0
# 4     691824.0
#
# [5 rows x 22 columns]

# %%
df.head()
# Out:
#     "recordID" state  account_length  area_code international_plan  \
# 0            1    HI             101        510                 no
# 1            2    MT             137        510                 no
# 2            3    OH             103        408                 no
# 3            4    NM              99        415                 no
# 4            5    SC             108        415                 no
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0              no                      0               70.9              123
# 1              no                      0              223.6               86
# 2             yes                     29              294.7               95
# 3              no                      0              216.8              123
# 4              no                      0              197.4               78
#
#    total_day_charge  ...  total_eve_charge  total_night_minutes  \
# 0             12.05  ...             18.01                236.0
# 1             38.01  ...             20.81                 94.2
# 2             50.10  ...             20.17                300.3
# 3             36.86  ...             10.74                220.6
# 4             33.56  ...             10.54                204.5
#
#    total_night_calls  total_night_charge  total_intl_minutes  \
# 0                 73               10.62                10.6
# 1                 81                4.24                 9.5
# 2                127               13.51                13.7
# 3                 82                9.93                15.7
# 4                107                9.20                 7.7
#
#    total_intl_calls  total_intl_charge  number_customer_service_calls  churn  \
# 0                 3               2.86                              3     no
# 1                 7               2.57                              0     no
# 2                 6               3.70                              1     no
# 3                 2               4.24                              1     no
# 4                 4               2.08                              2     no
#
#    customer_id
# 0   23383607.0
# 1   22550362.0
# 2   59063354.0
# 3   25464504.0
# 4     691824.0
#
# [5 rows x 22 columns]

# %%
df.columns[0]
# Out:
# ' "recordID"'

# %%
df.drop([' "recordID"','customer_id'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#        account_length     area_code  number_vmail_messages  total_day_minutes  \
# count    12892.000000  12892.000000           12892.000000       12892.000000
# mean       100.676621    437.133804               7.996665         180.162023
# std         39.806413     42.341820              13.641977          54.207056
# min          1.000000    408.000000               0.000000           0.000000
# 25%         73.000000    408.000000               0.000000         144.000000
# 50%        100.000000    415.000000               0.000000         180.000000
# 75%        127.000000    510.000000              19.000000         216.300000
# max        243.000000    510.000000              52.000000         351.500000
#
#        total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  \
# count     12892.000000      12892.000000       12892.000000     12892.000000
# mean        100.266599         30.628086         200.711852       100.137139
# std          19.946657          9.215171          50.781851        19.894032
# min           0.000000          0.000000           0.000000         0.000000
# 25%          87.000000         24.480000         166.200000        87.000000
# 50%         101.000000         30.600000         201.150000       100.000000
# 75%         114.000000         36.770000         234.900000       114.000000
# max         165.000000         59.760000         363.700000       170.000000
#
#        total_eve_charge  total_night_minutes  total_night_calls  \
# count      12892.000000         12892.000000       12892.000000
# mean          17.060717           200.557834         100.038241
# std            4.316445            50.632872          19.749714
# min            0.000000             0.000000           0.000000
# 25%           14.130000           167.000000          87.000000
# 50%           17.095000           200.800000         100.000000
# 75%           19.970000           235.100000         113.000000
# max           30.910000           395.000000         175.000000
#
#        total_night_charge  total_intl_minutes  total_intl_calls  \
# count        12892.000000        12892.000000      12892.000000
# mean             9.025192           10.244702          4.467654
# std              2.278507            2.782623          2.466493
# min              0.000000            0.000000          0.000000
# 25%              7.520000            8.500000          3.000000
# 50%              9.040000           10.300000          4.000000
# 75%             10.580000           12.100000          6.000000
# max             17.770000           20.000000         20.000000
#
#        total_intl_charge  number_customer_service_calls
# count       12892.000000                   12892.000000
# mean            2.766584                       1.563683
# std             0.751269                       1.310606
# min             0.000000                       0.000000
# 25%             2.300000                       1.000000
# 50%             2.780000                       1.000000
# 75%             3.270000                       2.000000
# max             5.400000                       9.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12892 entries, 0 to 12891
# Data columns (total 20 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   state                          12892 non-null  object
#  1   account_length                 12892 non-null  int64
#  2   area_code                      12892 non-null  int64
#  3   international_plan             12892 non-null  object
#  4   voice_mail_plan                12892 non-null  object
#  5   number_vmail_messages          12892 non-null  int64
#  6   total_day_minutes              12892 non-null  float64
#  7   total_day_calls                12892 non-null  int64
#  8   total_day_charge               12892 non-null  float64
#  9   total_eve_minutes              12892 non-null  float64
#  10  total_eve_calls                12892 non-null  int64
#  11  total_eve_charge               12892 non-null  float64
#  12  total_night_minutes            12892 non-null  float64
#  13  total_night_calls              12892 non-null  int64
#  14  total_night_charge             12892 non-null  float64
#  15  total_intl_minutes             12892 non-null  float64
#  16  total_intl_calls               12892 non-null  int64
#  17  total_intl_charge              12892 non-null  float64
#  18  number_customer_service_calls  12892 non-null  int64
#  19  churn                          12892 non-null  object
# dtypes: float64(8), int64(8), object(4)
# memory usage: 2.0+ MB

# %%
count = df.value_counts()
print(count)
# Out:
# state  account_length  area_code  international_plan  voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  total_night_minutes  total_night_calls  total_night_charge  total_intl_minutes  total_intl_calls  total_intl_charge  number_customer_service_calls  churn
# PA     122             415        yes                 no               0                      230.9              132              39.25             243.2              99               20.67             182.4                57                 8.21                11.0                2                 2.97               0                              yes      4
# SD     88              415        no                  no               0                      215.6              115              36.65             216.2              85               18.38             171.3                65                 7.71                11.8                1                 3.19               3                              no       4
# HI     72              415        no                  no               0                      109.1              97               18.55             115.7              96               9.83              295.8                84                 13.31               8.3                 6                 2.24               0                              no       4
# SD     65              408        no                  yes              31                     282.3              70               47.99             152.0              89               12.92             225.5                93                 10.15               12.0                4                 3.24               1                              no       4
# MD     136             415        no                  no               0                      250.2              121              42.53             267.1              118              22.70             151.0                114                6.80                13.0                2                 3.51               1                              yes      4
#                                                                                                                                                                                                                                                                                                                                                                       ..
# RI     106             415        no                  no               0                      155.9              90               26.50             198.0              101              16.83             189.1                95                 8.51                8.0                 2                 2.16               2                              no       1
#        105             408        no                  no               0                      104.2              75               17.71             272.9              91               23.20             187.2                107                8.42                9.2                 2                 2.48               1                              no       1
# ID     40              510        no                  no               0                      146.4              105              24.89             196.4              143              16.69             235.6                123                10.60               9.4                 3                 2.54               3                              no       1
# NH     74              510        no                  no               0                      233.6              72               39.71             168.0              103              14.28             276.3                71                 12.43               6.3                 2                 1.70               2                              no       1
# MS     79              415        no                  no               0                      161.6              94               27.47             187.5              110              15.94             220.8                71                 9.94                10.3                7                 2.78               2                              no       1
# Name: count, Length: 5000, dtype: int64

# %%
df['churn'].value_counts()
# Out:
# churn
# no     11069
# yes     1823
# Name: count, dtype: int64

# %% [markdown]
# The data is highly unbalanced, No(False class) is 11069 & Yes(True Class) is only 1823.
# The Ratio is very low.

# %%
df.isnull().sum()
# Out:
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %% [markdown]
# This dataset has no missing values

# %%
for col in df.columns:
    print(col,df[col].unique())
    print("---")
# Out:
# state ['HI' 'MT' 'OH' 'NM' 'SC' 'IA' 'ND' 'LA' 'MO' 'TX' 'AR' 'ME' 'DE' 'MN'
#  'KS' 'NC' 'NV' 'CO' 'TN' 'OR' 'NE' 'ID' 'WY' 'MD' 'AZ' 'VT' 'MS' 'CA'
#  'WI' 'SD' 'WV' 'MI' 'UT' 'NJ' 'MA' 'AL' 'FL' 'VA' 'IL' 'PA' 'RI' 'DC'
#  'IN' 'CT' 'GA' 'NY' 'NH' 'KY' 'WA' 'AK' 'OK']
# ---
# account_length [101 137 103  99 108 117  63  94 138 128 113 140 102  60  96 178  75 106
#  158 111  92  42  69  76  72 115  68  97  90  73  54 161 125 194 141  98
#  110  70  66  79  61  77 105 159  83  93 163 169  57  85 132 190  39  84
#   71 114 135  82  64 112 166 120 187 100  45  43  52  74  40  56 133 119
#  131 118 107 109 127  33 145  47  53 148  55 143 170  65 157  89  91 104
#  130  80 146  29  78 185 144  59 139  12 150 156  17 176  95 136 165 149
#  124  87  51 126  62  48  58  81  36 177  25 171 122  44 167  41 184  88
#  151 160 152  49  13 142   3  23  19 154 116 173  24  15  86 147  21 174
#  162 186  14   7   1  18  20  11 192 121 134  67 164 180  35 155  32 123
#  182 129  38  37  50  27 188 175   5  26   4  31 193 238  28 195 153 201
#  216 183 168 222 232 233  22  46  34   8 217   2 200 172  16  30 202 181
#   10   6 179 208 215 199 196 209 224 189 243 205   9 210 212 197 225 191
#  204 221]
# ---
# area_code [510 408 415]
# ---
# international_plan ['no' 'yes']
# ---
# voice_mail_plan ['no' 'yes']
# ---
# number_vmail_messages [ 0 29 32 43 39 22 25 35 31 38 41  6 37 30 40 33 36 12 21 46 27 20 18 24
#  28 34 15 26 45 49 19 17 16 14 23 42 10 47 48 52 44 51 11  8  4 13 50  9]
# ---
# total_day_minutes [ 70.9 223.6 294.7 ... 224.1 124.9 321.1]
# ---
# total_day_calls [123  86  95  78  85 124  97 117 100  77 109  93  66 105 121 142  88  99
#  101 111  94 110 125 106  74 131 112 104  76 113 122 127  65  91  48 120
#  102 103  81 108  83  56 118  75  57 132 114  92 126  98 119  87  82  96
#  107  90  64 133  89 115 147  58  72  80  53 128 130 149  79  68 143 141
#   61 116 148  84  62  60  51  73 135 137 151 136 134  50  71  70 129  52
#  138  69  59  67 144  63  47  34  39 156 157 146  44  46 140 152 139 160
#   49 145  55 158 163  54  36  40 150 165  30  42   0  45  35]
# ---
# total_day_charge [12.05 38.01 50.1  ... 38.1  21.23 54.59]
# ---
# total_eve_minutes [211.9 244.8 237.3 ... 153.4 288.8 265.9]
# ---
# total_eve_calls [ 73 139 105  88 101  68 125 112  46  89  90 116  97 107 100  81 108 104
#  106 120  71  70 131 128  91 109 126  75  87  78  94 127  62 103 110  96
#  136  67 148 117  95  98  92 111  99  63 119 123  93 102  86 121  56 118
#  114 133  76  79  65  85  72 113 115 132  84 143 130  83 124 142 150  74
#  129 138  61 122  80  77 134  82 151 147  58  69 141  66  55  64  47 144
#  169 149  53 140 152  54 154  60 135 145 155  51  52 137  38  57  44 146
#   49 164  59  48 168  42  37  12  50 157  45  36 156 153  43   0 159 170]
# ---
# total_eve_charge [18.01 20.81 20.17 ... 13.04 24.55 22.6 ]
# ---
# total_night_minutes [236.   94.2 300.3 ... 131.9 280.9 279.1]
# ---
# total_night_calls [ 73  81 127  82 107  90 120 106  71  92 100  94 124 119  89 114  99  98
#   95 104 121  80 125  78 105  96 103 115  79 101 132  72  85 110  83  84
#  109 118 134 116  64 113  88 123 135  56  68 148  76  93  91  97 141 102
#  139 136 131  58 129 112  49  48 128 122  77 151 145 108 130 117  69  53
#   66  40  87  70  75 111 168 149 137 161 133  67 138  65  60  74 126  61
#  150 143 140 146 159 142 160  57  86 170 158  63  62  52 147 154  42  41
#   59  50  38  46 155  12  55 165  54  43  51   0 152  44 153 175 157 144
#  166  33 156  36 164]
# ---
# total_night_charge [10.62  4.24 13.51 ...  5.12  5.65 12.37]
# ---
# total_intl_minutes [10.6  9.5 13.7 15.7  7.7  6.9 12.9 11.1  9.9 11.9  9.  10.5  7.2  7.4
#  14.3 11.7 13.9  7.1 14.7  9.8  9.3 11.   5.2  9.2 10.1 12.3  9.1 12.6
#  10.  12.  10.7 13.4  8.3 13.6 12.5 10.2  4.4  8.6  6.8 11.8 16.2 13.2
#   8.  11.4 12.4 10.4  7.5 12.8 18.9  7.6  0.  11.3 13.8  7.   9.6  8.8
#   7.3 15.1  7.9 11.6  6.1  8.7 13.3 10.3  5.7 10.9  7.8  5.6 13.5  9.7
#  14.8  8.9  9.4  8.5 12.7 15.4  5.4 14.   8.2  6.6 11.5 12.1 13.1 11.2
#   8.4 14.9  6.   6.3  4.5  8.1  6.2  3.9  4.6 12.2 13.   6.7 15.6 14.2
#  18.7 10.8  5.8 15.   5.9  4.3  5.5 16.8 14.5  4.8  5.3  4.7 16.1 14.1
#  15.2 15.3 16.5 16.3  3.1  5.1  6.5  3.7  3.8 17.2  4.2  0.4 19.3 14.6
#  19.2  6.4 16.6  2.2 15.9  5.  14.4 15.5  4.9 19.7 16.  15.8 17.8  3.4
#  18.5  3.5  4.1 16.4  4.   1.1  2.  17.7 20.  17.6  2.7 18.  17.5 18.2
#   3.6 16.7  1.3 16.9 17.  17.1 17.9 17.3 18.4  2.9  3.3  2.6 18.3  2.1
#   2.4  2.5]
# ---
# total_intl_calls [ 3  7  6  2  4  5  1  9  8 13  0 12 10 19 16 11 15 18 17 14 20]
# ---
# total_intl_charge [2.86 2.57 3.7  4.24 2.08 1.86 3.48 3.   2.67 3.21 2.43 2.84 1.94 2.
#  3.86 3.16 3.75 1.92 3.97 2.65 2.51 2.97 1.4  2.48 2.73 3.32 2.46 3.4
#  2.7  3.24 2.89 3.62 2.24 3.67 3.38 2.75 1.19 2.32 1.84 3.19 4.37 3.56
#  2.16 3.08 3.35 2.81 2.03 3.46 5.1  2.05 0.   3.05 3.73 1.89 2.59 2.38
#  1.97 4.08 2.13 3.13 1.65 2.35 3.59 2.78 1.54 2.94 2.11 1.51 3.65 2.62
#  4.   2.4  2.54 2.3  3.43 4.16 1.46 3.78 2.21 1.78 3.11 3.27 3.54 3.02
#  2.27 4.02 1.62 1.7  1.22 2.19 1.67 1.05 1.24 3.29 3.51 1.81 4.21 3.83
#  5.05 2.92 1.57 4.05 1.59 1.16 1.49 4.54 3.92 1.3  1.43 1.27 4.35 3.81
#  4.1  4.13 4.46 4.4  0.84 1.38 1.76 1.   1.03 4.64 1.13 0.11 5.21 3.94
#  5.18 1.73 4.48 0.59 4.29 1.35 3.89 4.19 1.32 5.32 4.32 4.27 4.81 0.92
#  5.   0.95 1.11 4.43 1.08 0.3  0.54 4.78 5.4  4.75 0.73 4.86 4.73 4.91
#  0.97 4.51 0.35 4.56 4.59 4.62 4.83 4.67 4.97 0.78 0.89 0.7  4.94 0.57
#  0.65 0.68]
# ---
# number_customer_service_calls [3 0 1 2 4 5 6 7 9 8]
# ---
# churn ['no' 'yes']
# ---

# %%
num_cols = df.select_dtypes(include=['number'])
obj_cols = df.select_dtypes(include=['object'])

# %%
print(f"Number\n{num_cols.columns}\n")
print(f"Object\n{obj_cols.columns}\n")
# Out:
# Number
# Index(['account_length', 'area_code', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_day_charge',
#        'total_eve_minutes', 'total_eve_calls', 'total_eve_charge',
#        'total_night_minutes', 'total_night_calls', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_calls', 'total_intl_charge',
#        'number_customer_service_calls'],
#       dtype='object')
#
# Object
# Index(['state', 'international_plan', 'voice_mail_plan', 'churn'], dtype='object')

# %% [markdown]
# Not of use
# - "recordID"
# - customer_id
#
# Features
# - state
# - account_length
# - area_code
# - international_plan
# - voice_mail_plan
# - number_vmail_messages
# - total_day_minutes
# - total_day_calls
# - total_day_charge
# - total_eve_minutes
# - total_eve_calls
# - total_eve_charge
# - total_night_minutes
# - total_night_calls
# - total_night_charge
# - total_intl_minutes
# - total_intl_calls
# - total_intl_charge
# - number_customer_service_calls
#
# Target Variable
# - churn

# %% [markdown]
# ## Visualisations

# %%
features = ["account_length","area_code", "voice_mail_plan", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls"]

fig, ax = plt.subplots(nrows=6,ncols=3, figsize=(18,20))
ax = ax.flat

for i,feature in enumerate(features):
    ax[i].hist(df[feature],bins=15,color='skyblue',edgecolor='black')
    ax[i].set_title(feature)
    ax[i].tick_params(axis='x',rotation=45)

for j in range(len(features),len(ax)):
    fig.delaxes(ax[j])

fig.tight_layout()
plt.show()

fig.savefig("figure.png")

# %%
def plot_histogram(df,column_name):

    plt.figure(figsize=(8,5))
    sns.histplot(df[column_name],kde=True)
    plt.title(f"Distribution of {column_name}")

    col_mean = df[column_name].mean()
    col_median = df[column_name].median()

    plt.axvline(col_mean,color='red',linestyle='--',label='Mean')
    plt.axvline(col_median, color='green',linestyle='-',label="Median")

    plt.legend()
    plt.show()

# %%
plot_histogram(df,"total_day_minutes")

# %%
df['total_day_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_minutes')
plt.xlabel('Days')
plt.ylabel('Mins')
plt.grid(True)
plt.show()

# %%
df['total_day_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_calls')
plt.xlabel('Days')
plt.ylabel('calls')
plt.grid(True)
plt.show()

# %%
df['total_day_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_charge')
plt.xlabel('Days')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_eve_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_minutes')
plt.xlabel('Eve')
plt.ylabel('Mins')
plt.grid(True)
plt.show()

# %%
df['total_eve_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_calls')
plt.xlabel('Eve')
plt.ylabel('Calls')
plt.grid(True)
plt.show()

# %%
df['total_eve_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_charge')
plt.xlabel('Eve')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_night_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_minutes')
plt.xlabel('Night')
plt.ylabel('Minutes')
plt.grid(True)
plt.show()

# %%
df['total_night_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_calls')
plt.xlabel('Night')
plt.ylabel('Calls')
plt.grid(True)
plt.show()

# %%
df['total_night_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_charge')
plt.xlabel('Night')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_intl_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_intl_minutes')
plt.xlabel('Intl')
plt.ylabel('Minutes')
plt.grid(True)
plt.show()

# %%
df['total_intl_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_intl_calls')
plt.xlabel('Intl')
plt.ylabel('Minute')
plt.grid(True)
plt.show()

# %%
df['total_intl_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_charge')
plt.xlabel('Intl')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outliers

# %%
features = ["account_length","area_code", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls" ]

plt.figure(figsize=(18, 10))

for i, column in enumerate(features, 1):
    plt.subplot(3, 6, i)  
    sns.boxplot(y=df[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
selected_cols  =  ["account_length","area_code", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls" ]


plt.figure(figsize=(16,10))
sns.heatmap(df[selected_cols].corr(),annot=True,fmt=".2f",cmap="coolwarm",linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %%
df
# Out:
#       state  account_length  area_code international_plan voice_mail_plan  \
# 0        HI             101        510                 no              no
# 1        MT             137        510                 no              no
# 2        OH             103        408                 no             yes
# 3        NM              99        415                 no              no
# 4        SC             108        415                 no              no
# ...     ...             ...        ...                ...             ...
# 12887    MT              25        415                 no              no
# 12888    MT             113        415                 no              no
# 12889    ID              88        415                 no             yes
# 12890    AK             120        415                 no              no
# 12891    UT              74        415                 no              no
#
#        number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                          0               70.9              123
# 1                          0              223.6               86
# 2                         29              294.7               95
# 3                          0              216.8              123
# 4                          0              197.4               78
# ...                      ...                ...              ...
# 12887                      0              134.3               98
# 12888                      0              215.9               93
# 12889                     31              181.6               91
# 12890                      0              178.4               97
# 12891                      0              106.4               84
#
#        total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  \
# 0                 12.05              211.9               73             18.01
# 1                 38.01              244.8              139             20.81
# 2                 50.10              237.3              105             20.17
# 3                 36.86              126.4               88             10.74
# 4                 33.56              124.0              101             10.54
# ...                 ...                ...              ...               ...
# 12887             22.83              202.3              109             17.20
# 12888             36.70              240.1               85             20.41
# 12889             30.87              213.2              120             18.12
# 12890             30.33              168.3              113             14.31
# 12891             18.09              140.2              104             11.92
#
#        total_night_minutes  total_night_calls  total_night_charge  \
# 0                    236.0                 73               10.62
# 1                     94.2                 81                4.24
# 2                    300.3                127               13.51
# 3                    220.6                 82                9.93
# 4                    204.5                107                9.20
# ...                    ...                ...                 ...
# 12887                195.9                100                8.82
# 12888                156.7                123                7.05
# 12889                207.8                104                9.35
# 12890                120.5                 93                5.42
# 12891                 90.9                 81                4.09
#
#        total_intl_minutes  total_intl_calls  total_intl_charge  \
# 0                    10.6                 3               2.86
# 1                     9.5                 7               2.57
# 2                    13.7                 6               3.70
# 3                    15.7                 2               4.24
# 4                     7.7                 4               2.08
# ...                   ...               ...                ...
# 12887                12.6                 5               3.40
# 12888                 4.9                 5               1.32
# 12889                11.4                 4               3.08
# 12890                 9.3                 9               2.51
# 12891                11.4                 3               3.08
#
#        number_customer_service_calls churn
# 0                                  3    no
# 1                                  0    no
# 2                                  1    no
# 3                                  1    no
# 4                                  2    no
# ...                              ...   ...
# 12887                              2    no
# 12888                              3    no
# 12889                              1    no
# 12890                              1    no
# 12891                              1    no
#
# [12892 rows x 20 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# # Summary

# %% [markdown]
# Dataset doesn't have any missing values.
#
# This dataset is highly inbalanced.
# - No(Positive Class),this means customer is not cancelling the subscription
# - Yes(Negative Class),this means that custoer is cancelling the subscription
