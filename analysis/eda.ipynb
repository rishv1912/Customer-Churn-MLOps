# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly as go

# %%
df_path = "../data/customer_data.csv"
df = pd.read_csv(df_path)

# %%
df.T
# Out:
#                                     0           1           2           3      \
#  "recordID"                             1           2           3           4
# state                                  HI          MT          OH          NM
# account_length                        101         137         103          99
# area_code                             510         510         408         415
# international_plan                     no          no          no          no
# voice_mail_plan                        no          no         yes          no
# number_vmail_messages                   0           0          29           0
# total_day_minutes                    70.9       223.6       294.7       216.8
# total_day_calls                       123          86          95         123
# total_day_charge                    12.05       38.01        50.1       36.86
# total_eve_minutes                   211.9       244.8       237.3       126.4
# total_eve_calls                        73         139         105          88
# total_eve_charge                    18.01       20.81       20.17       10.74
# total_night_minutes                 236.0        94.2       300.3       220.6
# total_night_calls                      73          81         127          82
# total_night_charge                  10.62        4.24       13.51        9.93
# total_intl_minutes                   10.6         9.5        13.7        15.7
# total_intl_calls                        3           7           6           2
# total_intl_charge                    2.86        2.57         3.7        4.24
# number_customer_service_calls           3           0           1           1
# churn                                  no          no          no          no
# customer_id                    23383607.0  22550362.0  59063354.0  25464504.0
#
#                                   4           5           6           7      \
#  "recordID"                           5           6           7           8
# state                                SC          IA          ND          LA
# account_length                      108         117          63          94
# area_code                           415         415         415         408
# international_plan                   no          no          no          no
# voice_mail_plan                      no          no         yes          no
# number_vmail_messages                 0           0          32           0
# total_day_minutes                 197.4       226.5       218.9       157.5
# total_day_calls                      78          85         124          97
# total_day_charge                  33.56       38.51       37.21       26.78
# total_eve_minutes                 124.0       141.6       214.3       224.5
# total_eve_calls                     101          68         125         112
# total_eve_charge                  10.54       12.04       18.22       19.08
# total_night_minutes               204.5       223.0       260.3       310.8
# total_night_calls                   107          90         120         106
# total_night_charge                  9.2       10.04       11.71       13.99
# total_intl_minutes                  7.7         6.9        12.9        11.1
# total_intl_calls                      4           5           3           6
# total_intl_charge                  2.08        1.86        3.48         3.0
# number_customer_service_calls         2           1           1           0
# churn                                no          no          no          no
# customer_id                    691824.0  24456543.0  29694916.0  69020915.0
#
#                                     8           9      ...       12882  \
#  "recordID"                             9          10  ...       12883
# state                                  MO          TX  ...          LA
# account_length                        138         128  ...          95
# area_code                             510         415  ...         415
# international_plan                     no          no  ...          no
# voice_mail_plan                        no         yes  ...          no
# number_vmail_messages                   0          43  ...           0
# total_day_minutes                    89.1       177.8  ...       141.1
# total_day_calls                       117         100  ...          84
# total_day_charge                    15.15       30.23  ...       23.99
# total_eve_minutes                   126.8       147.3  ...       211.4
# total_eve_calls                        46          89  ...         108
# total_eve_charge                    10.78       12.52  ...       17.97
# total_night_minutes                 190.5       194.2  ...       103.7
# total_night_calls                      71          92  ...         127
# total_night_charge                   8.57        8.74  ...        4.67
# total_intl_minutes                    9.9        11.9  ...         5.9
# total_intl_calls                        4           1  ...           6
# total_intl_charge                    2.67        3.21  ...        1.59
# number_customer_service_calls           2           0  ...           3
# churn                                  no          no  ...          no
# customer_id                    22612071.0  12721031.0  ...  37514486.0
#
#                                     12883       12884        12885  \
#  "recordID"                         12884       12885        12886
# state                                  ME          KS           KS
# account_length                         80         131           36
# area_code                             408         415          510
# international_plan                     no          no           no
# voice_mail_plan                       yes         yes           no
# number_vmail_messages                  31          28            0
# total_day_minutes                   166.4       249.6        178.6
# total_day_calls                        92          87           83
# total_day_charge                    28.29       42.43        30.36
# total_eve_minutes                   238.3       227.2        213.1
# total_eve_calls                        74         138          103
# total_eve_charge                    20.26       19.31        18.11
# total_night_minutes                 150.7       239.9        198.0
# total_night_calls                      84          92          119
# total_night_charge                   6.78        10.8         8.91
# total_intl_minutes                   10.7         7.6         10.9
# total_intl_calls                        4           3            5
# total_intl_charge                    2.89        2.05         2.94
# number_customer_service_calls           4           3            1
# churn                                  no          no           no
# customer_id                    58651613.0  15571763.0  317032456.0
#
#                                     12886      12887       12888       12889  \
#  "recordID"                         12887      12888       12889       12890
# state                                  NV         MT          MT          ID
# account_length                        180         25         113          88
# area_code                             510        415         415         415
# international_plan                     no         no          no          no
# voice_mail_plan                        no         no          no         yes
# number_vmail_messages                   0          0           0          31
# total_day_minutes                   139.0      134.3       215.9       181.6
# total_day_calls                        96         98          93          91
# total_day_charge                    23.63      22.83        36.7       30.87
# total_eve_minutes                   224.9      202.3       240.1       213.2
# total_eve_calls                        64        109          85         120
# total_eve_charge                    19.12       17.2       20.41       18.12
# total_night_minutes                 170.8      195.9       156.7       207.8
# total_night_calls                     118        100         123         104
# total_night_charge                   7.69       8.82        7.05        9.35
# total_intl_minutes                   15.7       12.6         4.9        11.4
# total_intl_calls                        5          5           5           4
# total_intl_charge                    4.24        3.4        1.32        3.08
# number_customer_service_calls           2          2           3           1
# churn                                  no         no          no          no
# customer_id                    28439289.0  3785730.0  25171109.0  12126991.0
#
#                                     12890       12891
#  "recordID"                         12891       12892
# state                                  AK          UT
# account_length                        120          74
# area_code                             415         415
# international_plan                     no          no
# voice_mail_plan                        no          no
# number_vmail_messages                   0           0
# total_day_minutes                   178.4       106.4
# total_day_calls                        97          84
# total_day_charge                    30.33       18.09
# total_eve_minutes                   168.3       140.2
# total_eve_calls                       113         104
# total_eve_charge                    14.31       11.92
# total_night_minutes                 120.5        90.9
# total_night_calls                      93          81
# total_night_charge                   5.42        4.09
# total_intl_minutes                    9.3        11.4
# total_intl_calls                        9           3
# total_intl_charge                    2.51        3.08
# number_customer_service_calls           1           1
# churn                                  no          no
# customer_id                    33084674.0  28432623.0
#
# [22 rows x 12892 columns]

# %%
df.describe()
# Out:
#         "recordID"  account_length     area_code  number_vmail_messages  \
# count  12892.00000    12892.000000  12892.000000           12892.000000
# mean    6446.50000      100.676621    437.133804               7.996665
# std     3721.74417       39.806413     42.341820              13.641977
# min        1.00000        1.000000    408.000000               0.000000
# 25%     3223.75000       73.000000    408.000000               0.000000
# 50%     6446.50000      100.000000    415.000000               0.000000
# 75%     9669.25000      127.000000    510.000000              19.000000
# max    12892.00000      243.000000    510.000000              52.000000
#
#        total_day_minutes  total_day_calls  total_day_charge  \
# count       12892.000000     12892.000000      12892.000000
# mean          180.162023       100.266599         30.628086
# std            54.207056        19.946657          9.215171
# min             0.000000         0.000000          0.000000
# 25%           144.000000        87.000000         24.480000
# 50%           180.000000       101.000000         30.600000
# 75%           216.300000       114.000000         36.770000
# max           351.500000       165.000000         59.760000
#
#        total_eve_minutes  total_eve_calls  total_eve_charge  \
# count       12892.000000     12892.000000      12892.000000
# mean          200.711852       100.137139         17.060717
# std            50.781851        19.894032          4.316445
# min             0.000000         0.000000          0.000000
# 25%           166.200000        87.000000         14.130000
# 50%           201.150000       100.000000         17.095000
# 75%           234.900000       114.000000         19.970000
# max           363.700000       170.000000         30.910000
#
#        total_night_minutes  total_night_calls  total_night_charge  \
# count         12892.000000       12892.000000        12892.000000
# mean            200.557834         100.038241            9.025192
# std              50.632872          19.749714            2.278507
# min               0.000000           0.000000            0.000000
# 25%             167.000000          87.000000            7.520000
# 50%             200.800000         100.000000            9.040000
# 75%             235.100000         113.000000           10.580000
# max             395.000000         175.000000           17.770000
#
#        total_intl_minutes  total_intl_calls  total_intl_charge  \
# count        12892.000000      12892.000000       12892.000000
# mean            10.244702          4.467654           2.766584
# std              2.782623          2.466493           0.751269
# min              0.000000          0.000000           0.000000
# 25%              8.500000          3.000000           2.300000
# 50%             10.300000          4.000000           2.780000
# 75%             12.100000          6.000000           3.270000
# max             20.000000         20.000000           5.400000
#
#        number_customer_service_calls   customer_id
# count                   12892.000000  1.289200e+04
# mean                        1.563683  2.830245e+11
# std                         1.310606  3.205835e+13
# min                         0.000000  3.400000e+01
# 25%                         1.000000  2.409909e+07
# 50%                         1.000000  3.219535e+07
# 75%                         2.000000  5.535319e+07
# max                         9.000000  3.640000e+15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12892 entries, 0 to 12891
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0    "recordID"                    12892 non-null  int64
#  1   state                          12892 non-null  object
#  2   account_length                 12892 non-null  int64
#  3   area_code                      12892 non-null  int64
#  4   international_plan             12892 non-null  object
#  5   voice_mail_plan                12892 non-null  object
#  6   number_vmail_messages          12892 non-null  int64
#  7   total_day_minutes              12892 non-null  float64
#  8   total_day_calls                12892 non-null  int64
#  9   total_day_charge               12892 non-null  float64
#  10  total_eve_minutes              12892 non-null  float64
#  11  total_eve_calls                12892 non-null  int64
#  12  total_eve_charge               12892 non-null  float64
#  13  total_night_minutes            12892 non-null  float64
#  14  total_night_calls              12892 non-null  int64
#  15  total_night_charge             12892 non-null  float64
#  16  total_intl_minutes             12892 non-null  float64
#  17  total_intl_calls               12892 non-null  int64
#  18  total_intl_charge              12892 non-null  float64
#  19  number_customer_service_calls  12892 non-null  int64
#  20  churn                          12892 non-null  object
#  21  customer_id                    12892 non-null  float64
# dtypes: float64(9), int64(9), object(4)
# memory usage: 2.2+ MB

# %%
count = df.value_counts()
print(count)
# Out:
#  "recordID"  state  account_length  area_code  international_plan  voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  total_day_charge  total_eve_minutes  total_eve_calls  total_eve_charge  total_night_minutes  total_night_calls  total_night_charge  total_intl_minutes  total_intl_calls  total_intl_charge  number_customer_service_calls  churn  customer_id
# 1            HI     101             510        no                  no               0                      70.9               123              12.05             211.9              73               18.01             236.0                73                 10.62               10.6                3                 2.86               3                              no     23383607.0     1
# 8600         RI     114             510        no                  yes              28                     225.8              94               38.39             193.0              117              16.41             232.4                100                10.46               8.4                 9                 2.27               4                              no     38714424.0     1
# 8590         DC     108             510        no                  no               0                      138.6              122              23.56             172.3              117              14.65             231.6                92                 10.42               9.8                 3                 2.65               1                              no     24130759.0     1
# 8591         TX     114             415        no                  no               0                      84.7               118              14.40             249.9              86               21.24             193.4                95                 8.70                14.5                8                 3.92               1                              no     35920842.0     1
# 8592         KS     92              408        yes                 no               0                      62.6               111              10.64             180.6              126              15.35             221.7                80                 9.98                10.4                2                 2.81               1                              yes    302050414.0    1
#                                                                                                                                                                                                                                                                                                                                                                                                 ..
# 4300         IA     89              415        no                  yes              35                     174.4              108              29.65             196.7              100              16.72             127.4                74                 5.73                11.8                3                 3.19               1                              no     7915192.0      1
# 4301         RI     63              415        no                  no               0                      180.5              126              30.69             230.0              98               19.55             232.5                73                 10.46               10.6                3                 2.86               0                              no     3337722.0      1
# 4302         AL     102             415        no                  no               0                      123.1              106              20.93             182.0              102              15.47             244.6                75                 11.01               12.6                7                 3.40               2                              no     23663461.0     1
# 4303         NC     76              510        no                  no               0                      165.7              94               28.17             257.4              80               21.88             170.8                114                7.69                10.0                4                 2.70               1                              no     30154942.0     1
# 12892        UT     74              415        no                  no               0                      106.4              84               18.09             140.2              104              11.92             90.9                 81                 4.09                11.4                3                 3.08               1                              no     28432623.0     1
# Name: count, Length: 12892, dtype: int64

# %%
df['churn'].value_counts()
# Out:
# churn
# no     11069
# yes     1823
# Name: count, dtype: int64

# %% [markdown]
# The data is highly unbalanced, No(False class) is 11069 & Yes(True Class) is only 1823.
# The Ratio is very low.

# %%
df.isnull().sum()
# Out:
#  "recordID"                      0
# state                            0
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_day_charge                 0
# total_eve_minutes                0
# total_eve_calls                  0
# total_eve_charge                 0
# total_night_minutes              0
# total_night_calls                0
# total_night_charge               0
# total_intl_minutes               0
# total_intl_calls                 0
# total_intl_charge                0
# number_customer_service_calls    0
# churn                            0
# customer_id                      0
# dtype: int64

# %% [markdown]
# This dataset has no missing values

# %%
int_cols = df.select_dtypes(include=['int'])
float_cols = df.select_dtypes(include=['float'])
obj_cols = df.select_dtypes(include=['object'])

# %%
print(f"Integer\n{int_cols.columns}\n")
print(f"Float\n{float_cols.columns}\n")
print(f"Object\n{obj_cols.columns}\n")
# Out:
# Integer
# Index([' "recordID"', 'account_length', 'area_code', 'number_vmail_messages',
#        'total_day_calls', 'total_eve_calls', 'total_night_calls',
#        'total_intl_calls', 'number_customer_service_calls'],
#       dtype='object')
#
# Float
# Index(['total_day_minutes', 'total_day_charge', 'total_eve_minutes',
#        'total_eve_charge', 'total_night_minutes', 'total_night_charge',
#        'total_intl_minutes', 'total_intl_charge', 'customer_id'],
#       dtype='object')
#
# Object
# Index(['state', 'international_plan', 'voice_mail_plan', 'churn'], dtype='object')

# %% [markdown]
# Not of use
# - "recordID"
# - customer_id
#
# Features
# - state
# - account_length
# - area_code
# - international_plan
# - voice_mail_plan
# - number_vmail_messages
# - total_day_minutes
# - total_day_calls
# - total_day_charge
# - total_eve_minutes
# - total_eve_calls
# - total_eve_charge
# - total_night_minutes
# - total_night_calls
# - total_night_charge
# - total_intl_minutes
# - total_intl_calls
# - total_intl_charge
# - number_customer_service_calls
#
# Target Variable
# - churn

# %% [markdown]
# ## Visualisations

# %%
features = ["account_length","area_code", "voice_mail_plan", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls" ]

fig, ax = plt.subplots(nrows=6,ncols=3, figsize=(18,20))
ax = ax.flat

for i,feature in enumerate(features):
    ax[i].hist(df[feature],bins=15,color='skyblue',edgecolor='black')
    ax[i].set_title(feature)
    ax[i].tick_params(axis='x',rotation=45)

for j in range(len(features),len(ax)):
    fig.delaxes(ax[j])

fig.tight_layout()
plt.show()

# %%
df['total_day_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_minutes')
plt.xlabel('Days')
plt.ylabel('Mins')
plt.grid(True)
plt.show()

# %%
df['total_day_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_calls')
plt.xlabel('Days')
plt.ylabel('calls')
plt.grid(True)
plt.show()

# %%
df['total_day_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_charge')
plt.xlabel('Days')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_eve_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_minutes')
plt.xlabel('Eve')
plt.ylabel('Mins')
plt.grid(True)
plt.show()

# %%
df['total_eve_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_calls')
plt.xlabel('Eve')
plt.ylabel('Calls')
plt.grid(True)
plt.show()

# %%
df['total_eve_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_charge')
plt.xlabel('Eve')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_night_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_minutes')
plt.xlabel('Night')
plt.ylabel('Minutes')
plt.grid(True)
plt.show()

# %%
df['total_night_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_calls')
plt.xlabel('Night')
plt.ylabel('Calls')
plt.grid(True)
plt.show()

# %%
df['total_night_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_charge')
plt.xlabel('Night')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_intl_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_intl_minutes')
plt.xlabel('Intl')
plt.ylabel('Minutes')
plt.grid(True)
plt.show()

# %%
df['total_intl_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_intl_calls')
plt.xlabel('Intl')
plt.ylabel('Minute')
plt.grid(True)
plt.show()

# %%
df['total_intl_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_charge')
plt.xlabel('Intl')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# # Summary

# %% [markdown]
# this dataset doesn't have any missing values.
