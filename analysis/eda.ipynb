# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly as go
import seaborn as sns

# %%
df_path = "../data/customer_data.csv"
df = pd.read_csv(df_path)

# %%
df.head()
# Out:
#     "recordID" state  account_length  area_code international_plan  \
# 0            1    HI             101        510                 no
# 1            2    MT             137        510                 no
# 2            3    OH             103        408                 no
# 3            4    NM              99        415                 no
# 4            5    SC             108        415                 no
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0              no                      0               70.9              123
# 1              no                      0              223.6               86
# 2             yes                     29              294.7               95
# 3              no                      0              216.8              123
# 4              no                      0              197.4               78
#
#    total_day_charge  ...  total_eve_charge  total_night_minutes  \
# ...

# %%
df.head()
# Out:
#     "recordID" state  account_length  area_code international_plan  \
# 0            1    HI             101        510                 no
# 1            2    MT             137        510                 no
# 2            3    OH             103        408                 no
# 3            4    NM              99        415                 no
# 4            5    SC             108        415                 no
#
#   voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  \
# 0              no                      0               70.9              123
# 1              no                      0              223.6               86
# 2             yes                     29              294.7               95
# 3              no                      0              216.8              123
# 4              no                      0              197.4               78
#
#    total_day_charge  ...  total_eve_charge  total_night_minutes  \
# ...

# %%
df.columns[0]
# Out:
# ' "recordID"'

# %%
df.drop([' "recordID"','customer_id','state','total_day_charge','total_eve_charge','total_night_charge','total_intl_charge'],axis=1,inplace=True)

# %%
df.describe()
# Out:
#        account_length     area_code  number_vmail_messages  total_day_minutes  \
# count    12892.000000  12892.000000           12892.000000       12892.000000
# mean       100.676621    437.133804               7.996665         180.162023
# std         39.806413     42.341820              13.641977          54.207056
# min          1.000000    408.000000               0.000000           0.000000
# 25%         73.000000    408.000000               0.000000         144.000000
# 50%        100.000000    415.000000               0.000000         180.000000
# 75%        127.000000    510.000000              19.000000         216.300000
# max        243.000000    510.000000              52.000000         351.500000
#
#        total_day_calls  total_eve_minutes  total_eve_calls  \
# count     12892.000000       12892.000000     12892.000000
# mean        100.266599         200.711852       100.137139
# std          19.946657          50.781851        19.894032
# ...

# %%
df
# Out:
#        account_length  area_code international_plan voice_mail_plan  \
# 0                 101        510                 no              no
# 1                 137        510                 no              no
# 2                 103        408                 no             yes
# 3                  99        415                 no              no
# 4                 108        415                 no              no
# ...               ...        ...                ...             ...
# 12887              25        415                 no              no
# 12888             113        415                 no              no
# 12889              88        415                 no             yes
# 12890             120        415                 no              no
# 12891              74        415                 no              no
#
#        number_vmail_messages  total_day_minutes  total_day_calls  \
# 0                          0               70.9              123
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12892 entries, 0 to 12891
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   account_length                 12892 non-null  int64
#  1   area_code                      12892 non-null  int64
#  2   international_plan             12892 non-null  object
#  3   voice_mail_plan                12892 non-null  object
#  4   number_vmail_messages          12892 non-null  int64
#  5   total_day_minutes              12892 non-null  float64
#  6   total_day_calls                12892 non-null  int64
#  7   total_eve_minutes              12892 non-null  float64
#  8   total_eve_calls                12892 non-null  int64
#  9   total_night_minutes            12892 non-null  float64
#  10  total_night_calls              12892 non-null  int64
#  11  total_intl_minutes             12892 non-null  float64
# ...

# %%
count = df.value_counts()
print(count)
# Out:
# account_length  area_code  international_plan  voice_mail_plan  number_vmail_messages  total_day_minutes  total_day_calls  total_eve_minutes  total_eve_calls  total_night_minutes  total_night_calls  total_intl_minutes  total_intl_calls  number_customer_service_calls  churn
# 243             510        no                  no               0                      95.5               92               163.7              63               264.2                118                6.6                 6                 2                              no       4
# 122             415        no                  no               0                      35.1               62               180.8              89               251.6                58                 12.7                2                 1                              no       4
# ...

# %%
df['churn'].value_counts()
# Out:
# churn
# no     11069
# yes     1823
# Name: count, dtype: int64

# %% [markdown]
# The data is highly unbalanced, No(False class) is 11069 & Yes(True Class) is only 1823.
# The Ratio is very low.

# %%
df.isnull().sum()
# Out:
# account_length                   0
# area_code                        0
# international_plan               0
# voice_mail_plan                  0
# number_vmail_messages            0
# total_day_minutes                0
# total_day_calls                  0
# total_eve_minutes                0
# total_eve_calls                  0
# total_night_minutes              0
# total_night_calls                0
# total_intl_minutes               0
# total_intl_calls                 0
# number_customer_service_calls    0
# churn                            0
# dtype: int64

# %% [markdown]
# This dataset has no missing values

# %%
for col in df.columns:
    print(col,df[col].unique())
    print("---")
# Out:
# account_length [101 137 103  99 108 117  63  94 138 128 113 140 102  60  96 178  75 106
#  158 111  92  42  69  76  72 115  68  97  90  73  54 161 125 194 141  98
#  110  70  66  79  61  77 105 159  83  93 163 169  57  85 132 190  39  84
#   71 114 135  82  64 112 166 120 187 100  45  43  52  74  40  56 133 119
#  131 118 107 109 127  33 145  47  53 148  55 143 170  65 157  89  91 104
#  130  80 146  29  78 185 144  59 139  12 150 156  17 176  95 136 165 149
#  124  87  51 126  62  48  58  81  36 177  25 171 122  44 167  41 184  88
#  151 160 152  49  13 142   3  23  19 154 116 173  24  15  86 147  21 174
#  162 186  14   7   1  18  20  11 192 121 134  67 164 180  35 155  32 123
#  182 129  38  37  50  27 188 175   5  26   4  31 193 238  28 195 153 201
#  216 183 168 222 232 233  22  46  34   8 217   2 200 172  16  30 202 181
#   10   6 179 208 215 199 196 209 224 189 243 205   9 210 212 197 225 191
#  204 221]
# ---
# area_code [510 408 415]
# ---
# international_plan ['no' 'yes']
# ...

# %%
num_cols = df.select_dtypes(include=['number'])
obj_cols = df.select_dtypes(include=['object'])

# %%
print(f"Number\n{num_cols.columns}\n")
print(f"Object\n{obj_cols.columns}\n")
# Out:
# Number
# Index(['account_length', 'area_code', 'number_vmail_messages',
#        'total_day_minutes', 'total_day_calls', 'total_eve_minutes',
#        'total_eve_calls', 'total_night_minutes', 'total_night_calls',
#        'total_intl_minutes', 'total_intl_calls',
#        'number_customer_service_calls'],
#       dtype='object')
#
# Object
# Index(['international_plan', 'voice_mail_plan', 'churn'], dtype='object')

# %% [markdown]
# Not of use
# - "recordID"
# - customer_id
#
# Features
# - state
# - account_length
# - area_code
# - international_plan
# - voice_mail_plan
# - number_vmail_messages
# - total_day_minutes
# - total_day_calls
# - total_day_charge
# - total_eve_minutes
# - total_eve_calls
# - total_eve_charge
# - total_night_minutes
# - total_night_calls
# - total_night_charge
# - total_intl_minutes
# - total_intl_calls
# - total_intl_charge
# - number_customer_service_calls
#
# Target Variable
# - churn

# %% [markdown]
# ## Visualisations

# %%
features = ["account_length","area_code", "voice_mail_plan", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls"]

fig, ax = plt.subplots(nrows=6,ncols=3, figsize=(18,20))
ax = ax.flat

for i,feature in enumerate(features):
    ax[i].hist(df[feature],bins=15,color='skyblue',edgecolor='black')
    ax[i].set_title(feature)
    ax[i].tick_params(axis='x',rotation=45)

for j in range(len(features),len(ax)):
    fig.delaxes(ax[j])

fig.tight_layout()
plt.show()

fig.savefig("figure.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/cust-churn/lib/python3.10/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'total_day_charge'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[103], line 9
#       6 ax = ax.flat
# ...

# %%
def plot_histogram(df,column_name):

    plt.figure(figsize=(8,5))
    sns.histplot(df[column_name],kde=True)
    plt.title(f"Distribution of {column_name}")

    col_mean = df[column_name].mean()
    col_median = df[column_name].median()

    plt.axvline(col_mean,color='red',linestyle='--',label='Mean')
    plt.axvline(col_median, color='green',linestyle='-',label="Median")

    plt.legend()
    plt.show()

# %%
plot_histogram(df,"total_day_minutes")

# %%
df['total_day_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_minutes')
plt.xlabel('Days')
plt.ylabel('Mins')
plt.grid(True)
plt.show()

# %%
df['total_day_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_calls')
plt.xlabel('Days')
plt.ylabel('calls')
plt.grid(True)
plt.show()

# %%
df['total_day_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_day_charge')
plt.xlabel('Days')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_eve_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_minutes')
plt.xlabel('Eve')
plt.ylabel('Mins')
plt.grid(True)
plt.show()

# %%
df['total_eve_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_calls')
plt.xlabel('Eve')
plt.ylabel('Calls')
plt.grid(True)
plt.show()

# %%
df['total_eve_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_eve_charge')
plt.xlabel('Eve')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_night_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_minutes')
plt.xlabel('Night')
plt.ylabel('Minutes')
plt.grid(True)
plt.show()

# %%
df['total_night_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_calls')
plt.xlabel('Night')
plt.ylabel('Calls')
plt.grid(True)
plt.show()

# %%
df['total_night_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_charge')
plt.xlabel('Night')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %%
df['total_intl_minutes'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_intl_minutes')
plt.xlabel('Intl')
plt.ylabel('Minutes')
plt.grid(True)
plt.show()

# %%
df['total_intl_calls'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_intl_calls')
plt.xlabel('Intl')
plt.ylabel('Minute')
plt.grid(True)
plt.show()

# %%
df['total_intl_charge'].hist(bins = 20, edgecolor = 'black')
plt.title('Histogram of total_night_charge')
plt.xlabel('Intl')
plt.ylabel('Charge')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Outliers

# %%
features = ["account_length","area_code", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls" ]

plt.figure(figsize=(18, 10))

for i, column in enumerate(features, 1):
    plt.subplot(3, 6, i)  
    sns.boxplot(y=df[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Correlation matrix

# %%
selected_cols  =  ["account_length","area_code", "number_vmail_messages", "total_day_minutes", "total_day_calls", 
"total_day_charge", "total_eve_minutes", "total_eve_calls", "total_eve_charge", "total_night_minutes", "total_night_calls", "total_night_charge", 
"total_intl_minutes", "total_intl_calls", "total_intl_charge","number_customer_service_calls" ]


plt.figure(figsize=(16,10))
sns.heatmap(df[selected_cols].corr(),annot=True,fmt=".2f",cmap="coolwarm",linewidths=0.5)
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# Need to drop these charge columns because these are higly correlated to the minutes column (1.00).
# - total_day_charge -> total_day_minutes
# - total_eve_charge -> total_eve_minutes
# - total_night_charge -> total_night_minutes
# - total_intl_charge -> total_intl_minutes

# %%
df
# Out:
#       state  account_length  area_code international_plan voice_mail_plan  \
# 0        HI             101        510                 no              no
# 1        MT             137        510                 no              no
# 2        OH             103        408                 no             yes
# 3        NM              99        415                 no              no
# 4        SC             108        415                 no              no
# ...     ...             ...        ...                ...             ...
# 12887    MT              25        415                 no              no
# 12888    MT             113        415                 no              no
# 12889    ID              88        415                 no             yes
# 12890    AK             120        415                 no              no
# 12891    UT              74        415                 no              no
#
#        number_vmail_messages  total_day_minutes  total_day_calls  \
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# # Summary

# %% [markdown]
# Dataset doesn't have any missing values.
#
# This dataset is highly inbalanced.
# - No(Positive Class),this means customer is not cancelling the subscription
# - Yes(Negative Class),this means that custoer is cancelling the subscription
